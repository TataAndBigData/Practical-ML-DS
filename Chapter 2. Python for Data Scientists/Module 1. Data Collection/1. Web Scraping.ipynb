# %% [markdown]
# # Web scraping
#
# ### Learning outcomes
# - learn how we can get data from website content
# - learn to get website HTML using python requests
# - parsing HTML using xpath
#
#
# So far we've looked at how we can get data from APIs, databases and files that we have locally. But what if we don't have any data?
#
# Or what if we want to get data from some website which doesn't have an API?
#
# In this case we could go to that website and copy the data into some workable format like a CSV file, one feature at a time. But this doesn't work well when you need a large dataset.
#
# Instead we can write python code to do this for us.
#
# ## The challenge: Scraping house data
#
# The problem we are faced with is the classic house price prediction task, for all of the houses on the property website Zoopla. Zoopla doesn't provide it's data in a structured format for free; it has no API, and no structured files that we can download.
#
# [This link shows houses listed for sale in London](https://www.zoopla.co.uk/new-homes/property/london/?q=London&results_sort=newest_listings&search_source=new-homes)
#
# If we want to build a dataset of houses from Zoopla's website, then we would have to:
#     1. Get the webpage content
#
#     2. Finding the elements containing features of each example house,
#
#     3. formatting them into a dictionary per example.
#
# Let's do this now.
#
# ## Step 1: Get website content
#
# ### What format does information on a website exist in?
#
# We know that websites don't just print data in a nice CSV or JSON format.
# They have content to display stuff to you in a way that makes sense, like buttons, on the page.
# This content is defined in a HTML file.
#
# They also have styling
#
# #### What is HTML?
#
# HTML stands for HyperText Markup Language. It consists of a tree structure of different types of web elements, like buttons, page divisions, images and more. This means that it is used to define what **content** is rendered on any webpage that you visit.
#
# HTML markdown contains elements/tags that may contain other elements/tags.
#
# Here is an example of some HTML markdown, and the page which it is rendered as.
#
# ![](./images/example_html.png)
#
# ### How can we get the website HTML, which contains data that we want?
#
# When you search for a URL in a browser, here's what happens:
# - your browser makes a GET request to the computer that serves requests from that URL endpoint
# - this computer knows what web content to send you back, so it sends it in a response to the request. This stuff includes the HTML of the page that you want to view.
# - Your browser gets the HTML, and knows how to present that type of data to you (it renders the webpage)
#
# The point here being that you can get the HTML, which defines the content for any site, by making a GET request to that website.
#
# Let's try that!
#
# We can use the requests library to get the HTML from a website

# %%
import requests # import the requests library
r = requests.get('https://www.zoopla.co.uk') # make a HTTP GET request to this website
html_string = r.text # the text attribute of this response is the HTML as a string
print(r.text)
# Out:
# <!DOCTYPE html>
# <html class="no-js" xmlns="https://www.w3.org/1999/xhtml" xml:lang="en" lang="en-GB" xmlns:fb="https://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/">
# <head>
#
#
#     <meta charset="utf-8" />
#     <title>Zoopla &gt; Search Property to Buy, Rent, House Prices, Estate Agents</title>
#
#
#         <meta name="description" content="Search for property with the UK's leading resource. Browse houses and flats for sale and to rent, and find estate agents in your area." />
#
#         <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" />
#
#     <meta name="p:domain_verify" content="be06f9b9d493189acc5cb456ca9a68e1" />
#     <meta name="verify-v1" content="5sGBRIBu2OitdItUbuozS0V22pWw4WXsMP8K15vIKD0=" />
#     <meta name="msvalidate.01" content="20BD4007B12CDB4977964997AB208472" />
#     <meta name="y_key" content="1a4dcbe953cadecb" />
#     <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">
#     <link rel="shortcut icon" type="image/x-icon" href="https://z.zoocdn.com/www/_b/static/images/favicon-37408e0919.ico" >
#
#         <meta name="twitter:card" content="summary" />
#     <meta name="twitter:app:name:iphone" content="zoopla" />
#     <meta name="twitter:app:id:iphone" content="380932800" />
#     <meta name="twitter:app:name:googleplay" content="zoopla" />
#     <meta name="twitter:app:id:googleplay" content="com.zoopla.activity" />
#
#         <meta name="twitter:app:url:iphone" content="zoopla:///" />
#         <meta name="twitter:app:url:googleplay" content="android-app://com.zoopla.activity/zoopla/" />
#
#
#
#
#         <meta property="fb:admins" content="100003926523449" />
#         <meta property="twitter:account_id" content="19903963" />
#
#
#
#
#     <meta name="alexaVerifyID" content="wewxzTLpGKQ6OiSsFdJY3s7-QvE">
#     <link href="https://plus.google.com/118429606719656973951" rel="publisher">
#
#
#     <link rel="apple-touch-icon-precomposed" href="https://z.zoocdn.com/www/_b/static/images/apple-touch-icon-precomposed-bb48e93eb2.png">
#
#
#     <link rel="dns-prefetch" href="//fonts.gstatic.com/">
#     <link rel="preconnect" href="//fonts.gstatic.com/" crossorigin>
#
#
#
#
#     <style>
#         @font-face {
#             font-family: 'Lato';
#             font-style: normal;
#             font-display: swap;
#             font-weight: 300;
#             src: local('Lato Light'), local('Lato-Light'), url(https://fonts.gstatic.com/s/lato/v15/S6u9w4BMUTPHh7USSwiPGQ3q5d0.woff2) format('woff2');
#             unicode-range: U+0000-00FF, U+0131, U+0152-0153, U+02BB-02BC, U+02C6, U+02DA, U+02DC, U+2000-206F, U+2074, U+20AC, U+2122, U+2191, U+2193, U+2212, U+2215, U+FEFF, U+FFFD;
#         }
#         @font-face {
#             font-family: 'Lato';
#             font-style: normal;
#             font-display: swap;
#             font-weight: 400;
#             src: local('Lato Regular'), local('Lato-Regular'), url(https://fonts.gstatic.com/s/lato/v15/S6uyw4BMUTPHjx4wXiWtFCc.woff2) format('woff2');
#             unicode-range: U+0000-00FF, U+0131, U+0152-0153, U+02BB-02BC, U+02C6, U+02DA, U+02DC, U+2000-206F, U+2074, U+20AC, U+2122, U+2191, U+2193, U+2212, U+2215, U+FEFF, U+FFFD;
#         }
#         @font-face {
#             font-family: 'Lato';
#             font-style: normal;
#             font-display: swap;
#             font-weight: 700;
#             src: local('Lato Bold'), local('Lato-Bold'), url(https://fonts.gstatic.com/s/lato/v15/S6u9w4BMUTPHh6UVSwiPGQ3q5d0.woff2) format('woff2');
#             unicode-range: U+0000-00FF, U+0131, U+0152-0153, U+02BB-02BC, U+02C6, U+02DA, U+02DC, U+2000-206F, U+2074, U+20AC, U+2122, U+2191, U+2193, U+2212, U+2215, U+FEFF, U+FFFD;
#         }
#         @font-face {
#             font-family: 'Lato';
#             font-style: normal;
#             font-display: swap;
#             font-weight: 900;
#             src: local('Lato Black'), local('Lato-Black'), url(https://fonts.gstatic.com/s/lato/v15/S6u9w4BMUTPHh50XSwiPGQ3q5d0.woff2) format('woff2');
#             unicode-range: U+0000-00FF, U+0131, U+0152-0153, U+02BB-02BC, U+02C6, U+02DA, U+02DC, U+2000-206F, U+2074, U+20AC, U+2122, U+2191, U+2193, U+2212, U+2215, U+FEFF, U+FFFD;
#         }
#         @font-face {
#             font-family: 'Droid Sans';
#             font-style: normal;
#             font-display: swap;
#             font-weight: 400;
#             src: local('Droid Sans Regular'), local('DroidSans-Regular'), url(https://fonts.gstatic.com/s/droidsans/v9/SlGVmQWMvZQIdix7AFxXkHNSbRYXags.woff2) format('woff2');
#             unicode-range: U+0000-00FF, U+0131, U+0152-0153, U+02BB-02BC, U+02C6, U+02DA, U+02DC, U+2000-206F, U+2074, U+20AC, U+2122, U+2191, U+2193, U+2212, U+2215, U+FEFF, U+FFFD;
#         }
#         @font-face {
#             font-family: 'Droid Sans';
#             font-style: normal;
#             font-display: swap;
#             font-weight: 700;
#             src: local('Droid Sans Bold'), local('DroidSans-Bold'), url(https://fonts.gstatic.com/s/droidsans/v9/SlGWmQWMvZQIdix7AFxXmMh3eDs1ZyHKpWg.woff2) format('woff2');
#             unicode-range: U+0000-00FF, U+0131, U+0152-0153, U+02BB-02BC, U+02C6, U+02DA, U+02DC, U+2000-206F, U+2074, U+20AC, U+2122, U+2191, U+2193, U+2212, U+2215, U+FEFF, U+FFFD;
#         }
#         @font-face {
#             font-family: 'fontello';
#             src: url('https://z.zoocdn.com/www/_b/static/fonts/fontello/fontello-7b2edeef13.eot?20419200');
#             src: url('https://z.zoocdn.com/www/_b/static/fonts/fontello/fontello-7b2edeef13.eot?20419200#iefix') format('embedded-opentype'),
#             url('https://z.zoocdn.com/www/_b/static/fonts/fontello/fontello-9a4ac85fb6.woff2?20419200') format('woff2'),
#             url('https://z.zoocdn.com/www/_b/static/fonts/fontello/fontello-d6c180409a.woff?20419200') format('woff'),
#             url('https://z.zoocdn.com/www/_b/static/fonts/fontello/fontello-5bb83b3c0e.ttf?20419200') format('truetype'),
#             url('https://z.zoocdn.com/www/_b/static/fonts/fontello/fontello-3f4013f757.svg?20419200#fontello') format('svg');
#             font-weight: normal;
#             font-style: normal;
#         }
#     </style>
#
#
#
#
#  <link rel="stylesheet" href="https://z.zoocdn.com/www/ub/zoopla/static/dist/css/zoopla.ui-b6b45c1bec.css">
#  <link rel="stylesheet" href="https://z.zoocdn.com/www/ub/zoopla/static/dist/css/zoopla.home-64deb4d509.css">
#
#
#
#
#
#         <link rel="canonical" href="https://www.zoopla.co.uk/">
#
#
#         <link rel="alternate" href="android-app://com.zoopla.activity/zoopla/" />
#
#
#
#
#     <script async src="https://client-scripts.api.zpg.co.uk/scv-baselayer/baselayer.0.0.2.min.js"></script>
#     <script async src="https://client-scripts.api.zpg.co.uk/scv-tracking/tracking.0.0.1.min.js"></script>
#
#     <script>
#
#         var html = document.getElementsByTagName("html")[0];
#         if ( html.className == "no-js" ) {
#             html.className = "js";
#         }
#
#         window.dataLayer = window.dataLayer || [];
#
#
#
#     </script>
#
#
#
#
#
#
#
#
#
#
#
# </head>
#
#     <body class="layout-fullbleed brand-zoopla " id="bhome">
#
#
#
#         <script>
#
#             (function(){
#
#     var config = {};
#
#
#
#     dataLayer.push( config );
#
#     dataLayer.push({"ab": {"130":"win_423_property_free_cta (original)","127":"value_377_hide_zindex (original)","90":"pp106_srp_valuation_banners (original)","129":"win_631_mini_application_booster (original)","22":"raiden_fa_email_all (original)","106":"win_291_photos_design (original)","141":"main_1636_to_rent_campaigns (original)","23":"move670__stu (original)","105":"win_160_valuation_page (original)","29":"rc1027_property_portfolios (original)","110":"win_154_sellers_journey (original)","123":"win_294_applicant_to_valuation (original)","27":"cons6722_popup (original)","3":"cons6531_ldp_lsrp_consents (original)","138":"main_1636_house_prices_campaigns (original)","114":"ta61_dynamic_affordablity (original)","115":"zpg_nh_new_search_journey (original)","15":"value_293_estimates_mvp (original)","69":"ac554_experian_ab (original)","24":"pp56_shorten_valuation_agents (original)","101":"value_294_property_design (original)","76":"en_234_cookie_overlay (original)","10":"raid_2444_agent_sponsorship (original)","140":"main_1636_for_sale_campaigns (original)"}});
#
#
#
#
# })();
#
#
#             dataLayer.push(
# {
#
#
#     "taxonomy": {"page":"/homepage/","country_code":"gb","signed_in_status":"signed out","brand":"zoopla","device":"desktop","os":"","platform":"desktop","brand_primary":"zoopla"},
#
#
#
#
#     "event": "pageshow"
#
# }
#  );
#
#
#
#         </script>
#
#
#
#         <noscript><iframe src="//www.googletagmanager.com/ns.html?id=GTM-WWL3"
# height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-WWL3');</script>
#
#
#
#
#
#
#
#
#         <a id="top"></a>
#
#
#
#
#
#
# <header id="main-header" itemscope itemtype="https://schema.org/WPHeader" class="main-header is-rwd">
#     <div class="container-wrap">
#         <a class="visually-hidden focusable" href="#mbody">
#             Skip to main content
#         </a>
#         <a id="logo" class="main-header__logo-link" href="/">
#             <span class="visually-hidden">
#                 Zoopla
#             </span>
#             <img aria-hidden="true" class="icon--logo" src="https://z.zoocdn.com/www/_b/static/images/logo-5ead14393a.svg" alt="">
#         </a>
#
#         <a class="mnav__toggle--main-open is-s" href="#main-nav" title="Open main navigation">
#                 <span class="visually-hidden">Menu</span>
#             <svg class="icon--menu" role="presentation" aria-hidden="true">
#                 <use xlink:href="/static/svg/sprite.zoopla.svg#icon-menu"></use>
#             </svg>
#         </a>
#
#
#
# <nav class="main-header__mnav" id="main-nav" itemscope itemtype="https://schema.org/SiteNavigationElement">
#
#
#
# <ul class="mnav mnav--account list--narrow mnav--manage">
#     <li class="mnav__item">
#         <a class="button button--tertiary-dark enquiry-link__text" rel="nofollow" href="/my-enquiries/" >
#             My enquiries
#         </a>
#     </li>
#     <li class="mnav__item">
#         <a class="button button--tertiary-dark main_header__manage" href="/property/track" data-ga-category="my home" data-ga-action="click" data-ga-label="uncookied" rel="nofollow" >View my home</a>
#     </li>
#     <li class="mnav__item">
#
#
#         <a class="button button--tertiary-dark account-link__text" href="/signin/" >
#             Sign in
#         </a>
#
#
#         <div class="subnav subnav--account">
#
#
#             <ul class="subnav-account__notifications list--narrow is-s">
#                 <li class="notifications__item">
#                     <a tabindex="-1" class="notifications__link" href="/myaccount/" data-ajax="false" title="Manage account" data-ga-category="User Account" data-ga-action="clickthrough" data-ga-label="user account&gt;manage account">
#                         <span class="notifications__text is-l">Manage account</span>
#                         <svg class="icon--cog" role="presentation" aria-hidden="true">
#                             <use xlink:href="/static/svg/sprite.zoopla.svg#icon-cog"></use>
#                         </svg>
#                     </a>
#                 </li>
#                 <li class="notifications__item">
#                     <a tabindex="-1" class="notifications__link" href="/myaccount/alerts-searches/" title="Alerts &amp; searches" data-ga-category="User Account" data-ga-action="clickthrough" data-ga-label="user account&gt;alerts &amp;amp; searches">
#                         <span class="notifications__text is-l">Alerts &amp; searches</span>
#                         <svg class="icon--bell" role="presentation" aria-hidden="true">
#                             <use xlink:href="/static/svg/sprite.zoopla.svg#icon-bell"></use>
#                         </svg>
#                     </a>
#                 </li>
#                 <li class="notifications__item">
#                     <a tabindex="-1" class="notifications__link" href="/myaccount/favourites/" title="Saved properties" data-ga-category="User Account" data-ga-action="clickthrough" data-ga-label="user account&gt;favourites">
#                         <span class="notifications__text is-l">Saved properties</span>
#                         <svg class="icon--star" role="presentation" aria-hidden="true">
#                             <use xlink:href="/static/svg/sprite.zoopla.svg#icon-star"></use>
#                         </svg>
#                     </a>
#                 </li>
#                 <li class="notifications__item">
#                     <a tabindex="-1" class="notifications__link" href="/myaccount/account/preferences/" title="Email preferences" data-ga-category="User Account" data-ga-action="clickthrough" data-ga-label="user account&gt;email preferences">
#                         <span class="notifications__text is-l">Email preferences</span>
#                         <svg class="icon--email" role="presentation" aria-hidden="true">
#                             <use xlink:href="/static/svg/sprite.zoopla.svg#icon-email"></use>
#                         </svg>
#                     </a>
#                 </li>
#             </ul>
#         </div>
#     </li>
# </ul>
#
#
#
#
#     <ul class="mnav mnav--primary list--narrow">
#
#
#
#
#         <li id="mn-buy" class="mnav__item mnav__item--expands">
#
#             <a data-ga-category="Navbar" data-ga-action="for sale_Channel page" data-ga-label="/tracking/homepage/"
#          class="mnav__link has-subnav" href="/for-sale/">
#
#                 For sale
#
#                     <svg class="icon--right is-s" role="presentation" aria-hidden="true"><use xlink:href="/static/svg/sprite.zoopla.svg#icon-arrow"></use></svg>
#
#             </a>
#
#             <div class="subnav subnav--double">
#
#                 <ul class="list--narrow">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             <li class="subnav__item">
#                 <a tabindex="-1" href="/for-sale/" class="subnav__link"
#
#                        data-ga-category="Navbar" data-ga-action="for sale_Property for sale" data-ga-label="/tracking/homepage/"
#                        >
#                     <strong>UK</strong>
#                     property for sale
#
#                 </a>
#             </li>
#
#
#
#
#
#
#
#
#
#
#
#
#             <li class="subnav__item">
#                 <a tabindex="-1" href="/new-homes/" class="subnav__link"
#
#                        data-ga-category="Navbar" data-ga-action="for sale_New homes for sale" data-ga-label="/tracking/homepage/"
#                        >
#                     <strong>UK</strong>
#                     new homes for sale
#
#                 </a>
#             </li>
#
#
#
#
#
#
#
#
#
#
#
#
#             <li class="subnav__item">
#                 <a tabindex="-1" href="/for-sale/commercial/" class="subnav__link"
#
#                        data-ga-category="Navbar" data-ga-action="for sale_Commercial property for sale" data-ga-label="/tracking/homepage/"
#                        >
#                     <strong>UK</strong>
#                     commercial property for sale
#
#                 </a>
#             </li>
#
#
#
#
#
#
#
#
#
#
#
#
#             <li class="subnav__item">
#                 <a tabindex="-1" href="/find-agents/estate-agents/" class="subnav__link"
#
#                        data-ga-category="Navbar" data-ga-action="for sale_Estate agents" data-ga-label="/tracking/homepage/"
#                        >
#                     <strong>UK</strong>
#                     estate agents
#
#                 </a>
#             </li>
#
#
#
#
#
#
#
#
#                 </ul>
#                 <ul class="list--narrow">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             <li class="subnav__item">
#                 <a tabindex="-1" href="/travel-time/" class="subnav__link"
#
#                        data-ga-category="Navbar" data-ga-action="for sale_Travel time search" data-ga-label="/tracking/homepage/"
#                        >
#                     Travel time search
#
#                 </a>
#             </li>
#
#
#
#
#
#
#
#
#
#
#
#
#             <li class="subnav__item">
#                 <a tabindex="-1" href="/smartmaps/" class="subnav__link"
#
#                        data-ga-category="Navbar" data-ga-action="for sale_Draw a map search" data-ga-label="/tracking/homepage/"
#                        >
#                     Draw a map search
#
#                 </a>
#             </li>
#
#
#
#
#
#
#
#
#
#
#
#
#             <li class="subnav__item">
#                 <a tabindex="-1" href="/overseas/" class="subnav__link"
#
#                        data-ga-category="Navbar" data-ga-action="for sale_Overseas property for sale" data-ga-label="/tracking/homepage/"
#                        >
#                     Overseas property for sale
#
#                 </a>
#             </li>
#
#
#
#
#
#
#
#
#
#
#
#
#                 </ul>
#
#
#     <div role="navigation" class="subnav__controls is-s">
#         <a tabindex="-1" class="mnav__toggle--subnav-close" href="#main-header" title="Back to main navigation">
#             <span class="visually-hidden">
#                 Back
#             </span>
#             <svg class="icon--left" role="presentation" aria-hidden="true"><use xlink:href="/static/svg/sprite.zoopla.svg#icon-arrow"></use></svg>
#         </a>
#         <a tabindex="-1" class="mnav__toggle--main-close" href="#main-header" title="Close navigation">
#             <span class="visually-hidden">
#                 Close menu
#             </span>
#             <svg class="icon--close" role="presentation" aria-hidden="true"><use xlink:href="/static/svg/sprite.zoopla.svg#icon-close"></use></svg>
#         </a>
#     </div>
#
#
#             </div>
#         </li>
#
#
#
#         <li id="mn-rent" class="mnav__item mnav__item--expands">
#
#             <a data-ga-category="Navbar" data-ga-action="to rent_Channel page" data-ga-label="/tracking/homepage/"
#          class="mnav__link has-subnav" href="/to-rent/">
#
#                 To rent
#
#                     <svg class="icon--right is-s" role="presentation" aria-hidden="true"><use xlink:href="/static/svg/sprite.zoopla.svg#icon-arrow"></use></svg>
#
#             </a>
#
#             <div class="subnav subnav--double">
#
#                 <ul class="list--narrow">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             <li class="subnav__item">
#                 <a tabindex="-1" href="/to-rent/" class="subnav__link"
#
#                        data-ga-category="Navbar" data-ga-action="to rent_Property to rent" data-ga-label="/tracking/homepage/"
#                        >
#                     <strong>UK</strong>
#                     property to rent
#
#                 </a>
#             </li>
#
#
#
#
#
#
#
#
#
#
#
#
#             <li class="subnav__item">
#                 <a tabindex="-1" href="/to-rent/commercial/" class="subnav__link"
#
#                        data-ga-category="Navbar" data-ga-action="to rent_Commercial property to let" data-ga-label="/tracking/homepage/"
#                        >
#                     <strong>UK</strong>
#                     commercial property to let
#
#                 </a>
#             </li>
#
#
#
#
#
#
#
#
#
#
#
#
#             <li class="subnav__item">
#                 <a tabindex="-1" href="/find-agents/letting-agents/" class="subnav__link"
#
#                        data-ga-category="Navbar" data-ga-action="to rent_Letting agents" data-ga-label="/tracking/homepage/"
#                        >
#                     <strong>UK</strong>
#                     letting agents
#
#                 </a>
#             </li>
#
#
#
#
#
#
#
#
#                 </ul>
#                 <ul class="list--narrow">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             <li class="subnav__item">
#                 <a tabindex="-1" href="/travel-time/?search-section=to-rent" class="subnav__link"
#
#                        data-ga-category="Navbar" data-ga-action="to rent_Travel time search" data-ga-label="/tracking/homepage/"
#                        >
#                     Travel time search
#
#                 </a>
#             </li>
#
#
#
#
#
#
#
#
#
#
#
#
#             <li class="subnav__item">
#                 <a tabindex="-1" href="/smartmaps/?section=to-rent" class="subnav__link"
#
#                        data-ga-category="Navbar" data-ga-action="to rent_Draw a map search" data-ga-label="/tracking/homepage/"
#                        >
#                     Draw a map search
#
#                 </a>
#             </li>
#
#
#
#
#
#
#
#
#
#
#
#
#                 </ul>
#
#
#     <div role="navigation" class="subnav__controls is-s">
#         <a tabindex="-1" class="mnav__toggle--subnav-close" href="#main-header" title="Back to main navigation">
#             <span class="visually-hidden">
#                 Back
#             </span>
#             <svg class="icon--left" role="presentation" aria-hidden="true"><use xlink:href="/static/svg/sprite.zoopla.svg#icon-arrow"></use></svg>
#         </a>
#         <a tabindex="-1" class="mnav__toggle--main-close" href="#main-header" title="Close navigation">
#             <span class="visually-hidden">
#                 Close menu
#             </span>
#             <svg class="icon--close" role="presentation" aria-hidden="true"><use xlink:href="/static/svg/sprite.zoopla.svg#icon-close"></use></svg>
#         </a>
#     </div>
#
#
#             </div>
#         </li>
#
#
#
#         <li id="mn-prices" class="mnav__item mnav__item--expands">
#
#             <a data-ga-category="Navbar" data-ga-action="house prices_Channel page" data-ga-label="/tracking/homepage/"
#          class="mnav__link has-subnav" href="/house-prices/">
#
#                 House prices
#
#                     <svg class="icon--right is-s" role="presentation" aria-hidden="true"><use xlink:href="/static/svg/sprite.zoopla.svg#icon-arrow"></use></svg>
#
#             </a>
#
#             <div class="subnav subnav--prices">
#
#                 <ul class="list--narrow">
#
#
#
#
#
#
#
#
#
#
#             <li class="subnav__item">
#                 <a tabindex="-1" href="/house-prices/" class="subnav__link"
#
#                        data-ga-category="Navbar" data-ga-action="house prices_House prices &amp; values" data-ga-label="/tracking/homepage/"
#                        >
#                     <strong>UK</strong>
#                     house prices &amp; values
#
#                 </a>
#             </li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             <li class="subnav__item">
#                 <a tabindex="-1" href="/market/" class="subnav__link"
#
#                        data-ga-category="Navbar" data-ga-action="house prices_Area stats" data-ga-label="/tracking/homepage/"
#                        >
#                     <strong>UK</strong>
#                     area stats
#
#                 </a>
#             </li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             <li class="subnav__item">
#                 <a tabindex="-1" href="/manage/" class="subnav__link"
#
#                        data-ga-category="Navbar" data-ga-action="house prices_Manage your home better" data-ga-label="/tracking/homepage/"
#                        >
#                     Manage your home better
#
#                 </a>
#             </li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             <li class="subnav__item">
#                 <a tabindex="-1" href="/home-values/" class="subnav__link"
#
#                        data-ga-category="Navbar" data-ga-action="house prices_How much is my home worth" data-ga-label="/tracking/homepage/"
#                        >
#                     How much is my home worth?
#
#                 </a>
#             </li>
#
#
#
#
#
#
#                 </ul>
#
#
#     <div role="navigation" class="subnav__controls is-s">
#         <a tabindex="-1" class="mnav__toggle--subnav-close" href="#main-header" title="Back to main navigation">
#             <span class="visually-hidden">
#                 Back
#             </span>
#             <svg class="icon--left" role="presentation" aria-hidden="true"><use xlink:href="/static/svg/sprite.zoopla.svg#icon-arrow"></use></svg>
#         </a>
#         <a tabindex="-1" class="mnav__toggle--main-close" href="#main-header" title="Close navigation">
#             <span class="visually-hidden">
#                 Close menu
#             </span>
#             <svg class="icon--close" role="presentation" aria-hidden="true"><use xlink:href="/static/svg/sprite.zoopla.svg#icon-close"></use></svg>
#         </a>
#     </div>
#
#
#             </div>
#         </li>
#
#
#
#         <li id="mn-new" class="mnav__item mnav__item--expands">
#
#             <a data-ga-category="Navbar" data-ga-action="new homes_Channel page" data-ga-label="/tracking/homepage/"
#          class="mnav__link has-subnav" href="/new-homes/">
#
#                 New homes
#
#                     <svg class="icon--right is-s" role="presentation" aria-hidden="true"><use xlink:href="/static/svg/sprite.zoopla.svg#icon-arrow"></use></svg>
#
#             </a>
#
#             <div class="subnav subnav--double">
#
#                 <ul class="list--narrow">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             <li class="subnav__item">
#                 <a tabindex="-1" href="/new-homes/" class="subnav__link"
#
#                        data-ga-category="Navbar" data-ga-action="new homes_New homes for sale" data-ga-label="/tracking/homepage/"
#                        >
#                     <strong>UK</strong>
#                     new homes for sale
#
#                 </a>
#             </li>
#
#
#
#
#
#
#
#
#
#
#
#
#             <li class="subnav__item">
#                 <a tabindex="-1" href="/new-homes/developers/" class="subnav__link"
#
#                        data-ga-category="Navbar" data-ga-action="new homes_New build developments" data-ga-label="/tracking/homepage/"
#                        >
#                     <strong>UK</strong>
#                     new build developments
#
#                 </a>
#             </li>
#
#
#
#
#
#
#
#
#                 </ul>
#                 <ul class="list--narrow">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             <li class="subnav__item">
#                 <a tabindex="-1" href="/help-to-buy/" class="subnav__link"
#
#                        data-ga-category="Navbar" data-ga-action="new homes_Help to buy" data-ga-label="/tracking/homepage/"
#                        >
#                     Help to Buy
#
#                 </a>
#             </li>
#
#
#
#
#
#
#
#
#
#
#
#
#             <li class="subnav__item">
#                 <a tabindex="-1" href="/shared-ownership/" class="subnav__link"
#
#                        data-ga-category="Navbar" data-ga-action="new homes_Shared ownership" data-ga-label="/tracking/homepage/"
#                        >
#                     Shared Ownership
#
#                 </a>
#             </li>
#
#
#
#
#
#
#
#
#
#
#
#
#             <li class="subnav__item">
#                 <a tabindex="-1" href="/retirement/" class="subnav__link"
#
#                        data-ga-category="Navbar" data-ga-action="new homes_Retirement" data-ga-label="/tracking/homepage/"
#                        >
#                     Retirement
#                     <sup class="alert-bubble alert-bubble--subnav">New</sup>
#
#                 </a>
#             </li>
#
#
#
#
#
#
#
#
#
#
#
#
#                 </ul>
#
#
#     <div role="navigation" class="subnav__controls is-s">
#         <a tabindex="-1" class="mnav__toggle--subnav-close" href="#main-header" title="Back to main navigation">
#             <span class="visually-hidden">
#                 Back
#             </span>
#             <svg class="icon--left" role="presentation" aria-hidden="true"><use xlink:href="/static/svg/sprite.zoopla.svg#icon-arrow"></use></svg>
#         </a>
#         <a tabindex="-1" class="mnav__toggle--main-close" href="#main-header" title="Close navigation">
#             <span class="visually-hidden">
#                 Close menu
#             </span>
#             <svg class="icon--close" role="presentation" aria-hidden="true"><use xlink:href="/static/svg/sprite.zoopla.svg#icon-close"></use></svg>
#         </a>
#     </div>
#
#
#             </div>
#         </li>
#
#
#
#         <li id="mn-commercial" class="mnav__item mnav__item--expands">
#
#             <a data-ga-category="Navbar" data-ga-action="commercial_Channel page" data-ga-label="/tracking/homepage/"
#          class="mnav__link has-subnav" href="/to-rent/commercial/">
#
#                 Commercial
#
#                     <svg class="icon--right is-s" role="presentation" aria-hidden="true"><use xlink:href="/static/svg/sprite.zoopla.svg#icon-arrow"></use></svg>
#
#             </a>
#
#             <div class="subnav subnav--commercial">
#
#                 <ul class="list--narrow">
#
#
#
#
#
#
#
#
#
#
#             <li class="subnav__item">
#                 <a tabindex="-1" href="/to-rent/commercial/" class="subnav__link"
#
#                        data-ga-category="Navbar" data-ga-action="commercial_Commercial property to let" data-ga-label="/tracking/homepage/"
#                        >
#                     <strong>UK</strong>
#                     commercial property to let
#
#                 </a>
#             </li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             <li class="subnav__item">
#                 <a tabindex="-1" href="/for-sale/commercial/" class="subnav__link"
#
#                        data-ga-category="Navbar" data-ga-action="commercial_Commercial property for sale" data-ga-label="/tracking/homepage/"
#                        >
#                     <strong>UK</strong>
#                     commercial property for sale
#
#                 </a>
#             </li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             <li class="subnav__item">
#                 <a tabindex="-1" href="/find-agents/commercial-agents/" class="subnav__link"
#
#                        data-ga-category="Navbar" data-ga-action="commercial_Commercial agents" data-ga-label="/tracking/homepage/"
#                        >
#                     <strong>UK</strong>
#                     commercial agents
#
#                 </a>
#             </li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             <li class="subnav__item">
#                 <a tabindex="-1" href="/commercial/space-calculator/" class="subnav__link"
#
#                        data-ga-category="Navbar" data-ga-action="commercial_Office space calculator" data-ga-label="/tracking/homepage/"
#                        >
#                     Office space calculator
#
#                 </a>
#             </li>
#
#
#
#
#
#
#                 </ul>
#
#
#     <div role="navigation" class="subnav__controls is-s">
#         <a tabindex="-1" class="mnav__toggle--subnav-close" href="#main-header" title="Back to main navigation">
#             <span class="visually-hidden">
#                 Back
#             </span>
#             <svg class="icon--left" role="presentation" aria-hidden="true"><use xlink:href="/static/svg/sprite.zoopla.svg#icon-arrow"></use></svg>
#         </a>
#         <a tabindex="-1" class="mnav__toggle--main-close" href="#main-header" title="Close navigation">
#             <span class="visually-hidden">
#                 Close menu
#             </span>
#             <svg class="icon--close" role="presentation" aria-hidden="true"><use xlink:href="/static/svg/sprite.zoopla.svg#icon-close"></use></svg>
#         </a>
#     </div>
#
#
#             </div>
#         </li>
#
#
#
#         <li id="mn-overseas" class="mnav__item mnav__item--expands">
#
#             <a data-ga-category="Navbar" data-ga-action="overseas_Channel page" data-ga-label="/tracking/homepage/"
#          class="mnav__link has-subnav" href="/overseas/">
#
#                 Overseas
#
#                     <svg class="icon--right is-s" role="presentation" aria-hidden="true"><use xlink:href="/static/svg/sprite.zoopla.svg#icon-arrow"></use></svg>
#
#             </a>
#
#             <div class="subnav subnav--double">
#
#                 <ul class="list--narrow">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             <li class="subnav__item">
#                 <a tabindex="-1" href="/overseas/" class="subnav__link"
#
#                        data-ga-category="Navbar" data-ga-action="overseas_Overseas property for sale" data-ga-label="/tracking/homepage/"
#                        >
#                     Overseas property for sale
#
#                 </a>
#             </li>
#
#
#
#
#
#
#
#
#
#
#
#
#             <li class="subnav__item">
#                 <a tabindex="-1" href="/find-agents/overseas-agents/" class="subnav__link"
#
#                        data-ga-category="Navbar" data-ga-action="overseas_Overseas agents" data-ga-label="/tracking/homepage/"
#                        >
#                     Overseas agents
#
#                 </a>
#             </li>
#
#
#
#
#
#
#
#
#
#
#
#
#             <li class="subnav__item">
#                 <a tabindex="-1" href="/overseas/currency-zone/" class="subnav__link"
#
#                        data-ga-category="Navbar" data-ga-action="overseas_Currency zone" data-ga-label="/tracking/homepage/"
#                        >
#                     Currency zone
#
#                 </a>
#             </li>
#
#
#
#
#
#
#
#
#                 </ul>
#                 <ul class="list--narrow">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             <li class="subnav__item">
#                 <a tabindex="-1" href="/overseas/property/spain/" class="subnav__link"
#
#                        data-ga-category="Navbar" data-ga-action="overseas_Property for sale in spain" data-ga-label="/tracking/homepage/"
#                        >
#                     Property for Sale in Spain
#
#                 </a>
#             </li>
#
#
#
#
#
#
#
#
#
#
#
#
#             <li class="subnav__item">
#                 <a tabindex="-1" href="/overseas/property/france/" class="subnav__link"
#
#                        data-ga-category="Navbar" data-ga-action="overseas_Property for sale in france" data-ga-label="/tracking/homepage/"
#                        >
#                     Property for Sale in France
#
#                 </a>
#             </li>
#
#
#
#
#
#
#
#
#
#
#
#
#             <li class="subnav__item">
#                 <a tabindex="-1" href="/overseas/property/portugal/" class="subnav__link"
#
#                        data-ga-category="Navbar" data-ga-action="overseas_Property for sale in portugal" data-ga-label="/tracking/homepage/"
#                        >
#                     Property for Sale in Portugal
#
#                 </a>
#             </li>
#
#
#
#
#
#
#
#
#
#
#
#
#             <li class="subnav__item">
#                 <a tabindex="-1" href="/overseas/property/united-states/" class="subnav__link"
#
#                        data-ga-category="Navbar" data-ga-action="overseas_Property for sale in the united states" data-ga-label="/tracking/homepage/"
#                        >
#                     Property for Sale in the United States
#
#                 </a>
#             </li>
#
#
#
#
#
#
#
#
#
#
#
#
#             <li class="subnav__item">
#                 <a tabindex="-1" href="/overseas/property/italy/" class="subnav__link"
#
#                        data-ga-category="Navbar" data-ga-action="overseas_Property for sale in italy" data-ga-label="/tracking/homepage/"
#                        >
#                     Property for Sale in Italy
#
#                 </a>
#             </li>
#
#
#
#
#
#
#
#
#
#
#
#
#                 </ul>
#
#
#     <div role="navigation" class="subnav__controls is-s">
#         <a tabindex="-1" class="mnav__toggle--subnav-close" href="#main-header" title="Back to main navigation">
#             <span class="visually-hidden">
#                 Back
#             </span>
#             <svg class="icon--left" role="presentation" aria-hidden="true"><use xlink:href="/static/svg/sprite.zoopla.svg#icon-arrow"></use></svg>
#         </a>
#         <a tabindex="-1" class="mnav__toggle--main-close" href="#main-header" title="Close navigation">
#             <span class="visually-hidden">
#                 Close menu
#             </span>
#             <svg class="icon--close" role="presentation" aria-hidden="true"><use xlink:href="/static/svg/sprite.zoopla.svg#icon-close"></use></svg>
#         </a>
#     </div>
#
#
#             </div>
#         </li>
#
#
#
#         <li id="mn-agents" class="mnav__item mnav__item--expands">
#
#             <a data-ga-category="Navbar" data-ga-action="find agents_Channel page" data-ga-label="/tracking/homepage/"
#          class="mnav__link has-subnav" href="/find-agents/">
#
#                 Find agents
#
#                     <svg class="icon--right is-s" role="presentation" aria-hidden="true"><use xlink:href="/static/svg/sprite.zoopla.svg#icon-arrow"></use></svg>
#
#             </a>
#
#             <div class="subnav subnav--double subnav--agents">
#
#                 <ul class="list--narrow">
#
#
#
#
#
#
#
#
#
#         <li class="subnav__item">
#             <p class="subnav__title">I need an agent</p>
#         </li>
#
#
#
#
#
#
#
#
#
#
#             <li class="subnav__item">
#                 <a tabindex="-1" href="/find-agents/estate-agents/" class="subnav__link"
#
#                        data-ga-category="Navbar" data-ga-action="find agents_Estate agents" data-ga-label="/tracking/homepage/"
#                        >
#                     <strong>UK</strong>
#                     estate agents
#
#                 </a>
#             </li>
#
#
#
#
#
#
#
#
#
#
#
#
#             <li class="subnav__item">
#                 <a tabindex="-1" href="/find-agents/letting-agents/" class="subnav__link"
#
#                        data-ga-category="Navbar" data-ga-action="find agents_Letting agents" data-ga-label="/tracking/homepage/"
#                        >
#                     <strong>UK</strong>
#                     letting agents
#
#                 </a>
#             </li>
#
#
#
#
#
#
#
#
#
#
#
#
#             <li class="subnav__item">
#                 <a tabindex="-1" href="/find-agents/commercial-agents/" class="subnav__link"
#
#                        data-ga-category="Navbar" data-ga-action="find agents_Commercial agents" data-ga-label="/tracking/homepage/"
#                        >
#                     <strong>UK</strong>
#                     commercial agents
#
#                 </a>
#             </li>
#
#
#
#
#
#
#
#
#
#
#
#
#             <li class="subnav__item">
#                 <a tabindex="-1" href="/find-agents/overseas-agents/" class="subnav__link"
#
#                        data-ga-category="Navbar" data-ga-action="find agents_Overseas agents" data-ga-label="/tracking/homepage/"
#                        >
#                     Overseas agents
#
#                 </a>
#             </li>
#
#
#
#
#
#
#
#
#
#
#
#
#             <li class="subnav__item">
#                 <a tabindex="-1" href="/award-winning-agents/" class="subnav__link"
#
#                        data-ga-category="Navbar" data-ga-action="find agents_Award winning agents" data-ga-label="/tracking/homepage/"
#                        >
#                     Award winning agents
#
#                 </a>
#             </li>
#
#
#
#
#
#
#
#
#
#
#
#
#             <li class="subnav__item">
#                 <a tabindex="-1" href="/valuation/" class="subnav__link"
#
#                        data-ga-category="Navbar" data-ga-action="find agents_Get agent valuation" data-ga-label="/tracking/homepage/"
#                        >
#                     Get agent valuation
#
#                 </a>
#             </li>
#
#
#
#
#
#
#
#
#                 </ul>
#                 <ul class="list--narrow">
#
#
#
#
#
#
#
#
#
#
#
#
#         <li class="subnav__item">
#             <p class="subnav__title">I'm an agent</p>
#         </li>
#
#
#
#
#
#
#
#
#
#
#             <li class="subnav__item">
#                 <a tabindex="-1" href="/for-agents-and-developers/" class="subnav__link"
#
#                        data-ga-category="Navbar" data-ga-action="find agents_List with zoopla and build your business today" data-ga-label="/tracking/homepage/"
#                        >
#                     List with Zoopla and build your business today
#
#                 </a>
#             </li>
#
#
#
#
#
#
#
#
#
#
#
#
#             <li class="subnav__item">
#                 <a tabindex="-1" href="/for-agents-and-developers/" class="button button--secondary"
#
#                        data-ga-category="Navbar" data-ga-action="find agents_Find out more" data-ga-label="/tracking/homepage/"
#                        >
#                     Find out more
#
#                 </a>
#             </li>
#
#
#
#
#
#
#
#
#
#
#
#
#             <li class="subnav__item">
#                 <a tabindex="-1" href="https://pro.zoopla.co.uk/login" class="subnav__link"
#
#                        data-ga-category="Navbar" data-ga-action="find agents_I m a zoopla agent i want to login to zooplapro" data-ga-label="/tracking/homepage/"
#                        >
#                     I&#39;m a Zoopla agent, I want to login to ZooplaPro
#
#                 </a>
#             </li>
#
#
#
#
#
#
#
#
#
#
#
#
#             <li class="subnav__item">
#                 <a tabindex="-1" href="https://pro.zoopla.co.uk/login" class="button button--secondary"
#
#                        data-ga-category="Navbar" data-ga-action="find agents_Login" data-ga-label="/tracking/homepage/"
#                        >
#                     Login
#
#                 </a>
#             </li>
#
#
#
#
#
#
#
#
#
#
#
#
#                 </ul>
#
#
#     <div role="navigation" class="subnav__controls is-s">
#         <a tabindex="-1" class="mnav__toggle--subnav-close" href="#main-header" title="Back to main navigation">
#             <span class="visually-hidden">
#                 Back
#             </span>
#             <svg class="icon--left" role="presentation" aria-hidden="true"><use xlink:href="/static/svg/sprite.zoopla.svg#icon-arrow"></use></svg>
#         </a>
#         <a tabindex="-1" class="mnav__toggle--main-close" href="#main-header" title="Close navigation">
#             <span class="visually-hidden">
#                 Close menu
#             </span>
#             <svg class="icon--close" role="presentation" aria-hidden="true"><use xlink:href="/static/svg/sprite.zoopla.svg#icon-close"></use></svg>
#         </a>
#     </div>
#
#
#             </div>
#         </li>
#
#
#
#         <li id="mn-advice" class="mnav__item mnav__item--expands">
#
#             <a data-ga-category="Navbar" data-ga-action="discover_Channel page" data-ga-label="/tracking/homepage/"
#          class="mnav__link has-subnav" href="/discover/">
#
#                 Discover
#
#                     <svg class="icon--right is-s" role="presentation" aria-hidden="true"><use xlink:href="/static/svg/sprite.zoopla.svg#icon-arrow"></use></svg>
#
#             </a>
#
#             <div class="subnav subnav--triple" role="navigation">
#
#                 <ul class="list--narrow">
#
#
#
#
#
#
#
#
#
#         <li class="subnav__item">
#             <p class="subnav__title">Latest property news</p>
#         </li>
#
#
#
#
#
#
#
#
#
#
#             <li class="subnav__item item--news">
#                 <a tabindex="-1"
#                     data-ga-category="Navbar" data-ga-action="discover_Latest property news" data-ga-label="/tracking/homepage/"
#          class="subnav__link--news" href="/discover/property-news/zoopla-house-price-index-may-2020/">
#                     Zoopla House Price Index - May 2020
#                 </a>
#
#                 <time class="subnav__item-date" datetime="2020-06-23 00:00:00">
#
# June 23, 2020
#
#
#                 </time>
#
#             </li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#             <li class="subnav__item item--news">
#                 <a tabindex="-1"
#                     data-ga-category="Navbar" data-ga-action="discover_Latest property news" data-ga-label="/tracking/homepage/"
#          class="subnav__link--news" href="/discover/property-news/lenders-continue-to-withdraw-mortgages-for-borrowers-with-small-deposits/">
#                     Lenders continue to withdraw mortgages for borrowers with small deposits
#                 </a>
#
#                 <time class="subnav__item-date" datetime="2020-06-22 00:00:00">
#
# June 22, 2020
#
#
#                 </time>
#
#             </li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#             <li class="subnav__item item--news">
#                 <a tabindex="-1"
#                     data-ga-category="Navbar" data-ga-action="discover_Latest property news" data-ga-label="/tracking/homepage/"
#          class="subnav__link--news" href="/discover/property-news/look-inside-our-most-viewed-homes-since-the-market-reopened/">
#                     Look inside our most-viewed homes since the market reopened
#                 </a>
#
#                 <time class="subnav__item-date" datetime="2020-06-18 00:00:00">
#
# June 18, 2020
#
#
#                 </time>
#
#             </li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             <li class="subnav__item">
#                 <a tabindex="-1" href="/discover/property-news/" class="subnav__link"
#
#                        data-ga-category="Navbar" data-ga-action="discover_All property news" data-ga-label="/tracking/homepage/"
#                        >
#                     All property news
#                         <svg class="icon--right is-s" role="presentation" aria-hidden="true"><use xlink:href="/static/svg/sprite.zoopla.svg#icon-arrow"></use></svg>
#
#                 </a>
#             </li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 </ul>
#                 <ul class="list--narrow">
#
#
#
#
#
#
#
#
#
#
#
#
#         <li class="subnav__item">
#             <p class="subnav__title">Guides</p>
#         </li>
#
#
#
#
#
#
#
#
#
#
#             <li class="subnav__item">
#                 <a tabindex="-1" href="/worth/zooploma/" class="subnav__link"
#
#                        data-ga-category="Navbar" data-ga-action="discover_Zooplomas" data-ga-label="/tracking/homepage/"
#                        >
#                     Zooplomas
#
#                 </a>
#             </li>
#
#
#
#
#
#
#
#
#
#
#
#
#             <li class="subnav__item">
#                 <a tabindex="-1" href="/discover/" class="subnav__link"
#
#                        data-ga-category="Navbar" data-ga-action="discover_Property guides" data-ga-label="/tracking/homepage/"
#                        >
#                     Property guides
#
#                 </a>
#             </li>
#
#
#
#
#
#
#
#
#
#
#
#
#             <li class="subnav__item">
#                 <a tabindex="-1" href="/moving/buyers-guide/" class="subnav__link"
#
#                        data-ga-category="Navbar" data-ga-action="discover_Clickthrough" data-ga-label="move&gt;moving guide for buyers"
#                        >
#                     Moving guides for buyers
#
#                 </a>
#             </li>
#
#
#
#
#
#
#
#
#
#
#
#
#             <li class="subnav__item">
#                 <a tabindex="-1" href="/moving/renters-guide/" class="subnav__link"
#
#                        data-ga-category="Navbar" data-ga-action="discover_Clickthrough" data-ga-label="move&gt;moving guide for renters"
#                        >
#                     Moving guides for renters
#
#                 </a>
#             </li>
#
#
#
#
#
#
#
#
#
#
#
#
#             <li class="subnav__item">
#                 <a tabindex="-1" href="/runningcosts/" class="subnav__link"
#
#                        data-ga-category="Navbar" data-ga-action="discover_Running costs" data-ga-label="/tracking/homepage/"
#                        >
#                     Running Costs
#
#                 </a>
#             </li>
#
#
#
#
#
#
#
#
#
#
#
#
#             <li class="subnav__item">
#                 <a tabindex="-1" href="/treehouse/" class="subnav__link"
#
#                        data-ga-category="Navbar" data-ga-action="discover_Treehouse" data-ga-label="/tracking/homepage/"
#                        >
# ...
#                             data-track-label="linkedin" rel="noopener noreferrer" title="This link opens in a new window"
#                             class="eh8rboe0 css-190kehk e469udr0"><span role="presentation" aria-hidden="true" data-testid="linkedin" color="grey-aluminium" class="e5cetgg0 css-13falfm e1dxqi130"><svg viewBox="0 0 30 30" xmlns="http://www.w3.org/2000/svg"><path d="M25.563 25.564h-4.446v-6.963c0-1.66-.03-3.795-2.312-3.795-2.315 0-2.67 1.808-2.67 3.675v7.083h-4.447V11.247h4.268v1.956h.06c.594-1.125 2.045-2.312 4.21-2.312 4.506 0 5.337 2.965 5.337 6.82v7.853zM6.673 9.29a2.58 2.58 0 110-5.16 2.58 2.58 0 010 5.16zM4.449 25.564h4.45V11.247h-4.45v14.317zM27.779 0H2.214C.993 0 0 .968 0 2.162v25.673C0 29.03.993 30 2.214 30H27.78C29.003 30 30 29.03 30 27.835V2.162C30 .968 29.003 0 27.78 0z" fill-rule="evenodd"></path></svg></span><span class="css-1rwwusq e1xr6nc2">Zoopla LinkedIn profile</span></a>
#                         </li>
#                         <li class="css-1b9jro8 e1xr6nc1"><a href="https://www.instagram.com/zoopla" target="_blank" data-testid="social-link-instagram"
#                             data-track-category="footer" data-track-action="clickout" data-track-label="instagram"
#                             rel="noopener noreferrer" title="This link opens in a new window" class="eh8rboe0 css-190kehk e469udr0"><span role="presentation" aria-hidden="true" data-testid="instagram" color="grey-aluminium" class="e5cetgg0 css-13falfm e1dxqi130"><svg viewBox="0 0 30 30" xmlns="http://www.w3.org/2000/svg"><g fill-rule="evenodd"><path d="M14.995.01c-4.072 0-4.583.017-6.182.09-1.596.072-2.686.326-3.64.697a7.35 7.35 0 00-2.656 1.73 7.35 7.35 0 00-1.73 2.655c-.37.954-.624 2.044-.697 3.64-.073 1.6-.09 2.11-.09 6.183 0 4.072.017 4.583.09 6.182.073 1.596.327 2.686.697 3.64a7.35 7.35 0 001.73 2.656 7.351 7.351 0 002.656 1.73c.954.37 2.044.624 3.64.697 1.6.073 2.11.09 6.182.09 4.073 0 4.583-.017 6.183-.09 1.596-.073 2.686-.327 3.64-.697a7.351 7.351 0 002.656-1.73 7.351 7.351 0 001.73-2.656c.37-.954.623-2.044.696-3.64.073-1.6.09-2.11.09-6.182 0-4.073-.017-4.583-.09-6.183-.072-1.596-.326-2.686-.697-3.64a7.351 7.351 0 00-1.73-2.656 7.35 7.35 0 00-2.655-1.73c-.954-.37-2.044-.624-3.64-.696-1.6-.073-2.11-.09-6.183-.09zm0 2.701c4.004 0 4.478.016 6.06.088 1.462.066 2.256.31 2.784.516.7.272 1.2.597 1.724 1.122.525.524.85 1.024 1.122 1.724.205.528.45 1.322.516 2.784.072 1.582.088 2.056.088 6.06s-.016 4.478-.088 6.06c-.066 1.461-.31 2.255-.516 2.784-.272.7-.597 1.199-1.122 1.724a4.645 4.645 0 01-1.724 1.121c-.528.206-1.322.45-2.784.517-1.581.072-2.056.087-6.06.087s-4.478-.015-6.06-.087c-1.461-.067-2.255-.311-2.784-.517-.7-.272-1.199-.597-1.724-1.121a4.646 4.646 0 01-1.121-1.724c-.206-.529-.45-1.323-.517-2.785-.072-1.581-.087-2.055-.087-6.06 0-4.003.015-4.477.087-6.059.067-1.462.311-2.256.517-2.784.272-.7.597-1.2 1.121-1.724a4.645 4.645 0 011.724-1.122c.529-.205 1.323-.45 2.785-.516 1.581-.072 2.055-.088 6.06-.088z"></path><path d="M14.995 20.003a4.998 4.998 0 110-9.997 4.998 4.998 0 010 9.997zm-7.7-4.998a7.7 7.7 0 1015.4 0 7.7 7.7 0 00-15.4 0zM23 8.8a1.8 1.8 0 110-3.6 1.8 1.8 0 010 3.6z"></path></g></svg></span><span class="css-1rwwusq e1xr6nc2">Zoopla Instagram feed</span></a>
#                         </li>
#                         <li class="css-1b9jro8 e1xr6nc1"><a href="https://www.youtube.com/user/ZooplaUK" target="_blank" data-testid="social-link-youtube"
#                             data-track-category="footer" data-track-action="clickout" data-track-label="youtube"
#                             rel="noopener noreferrer" title="This link opens in a new window" class="eh8rboe0 css-190kehk e469udr0"><span role="presentation" aria-hidden="true" data-testid="youtube" color="grey-aluminium" class="e5cetgg0 css-13falfm e1dxqi130"><svg viewBox="0 0 33 23" xmlns="http://www.w3.org/2000/svg"><path d="M13.126 15.742l-.002-9.188 8.94 4.61-8.938 4.578zm19.626-10.78s-.323-2.254-1.315-3.246C30.179.414 28.769.407 28.122.33 23.492 0 16.548 0 16.548 0h-.014S9.59 0 4.96.33c-.646.077-2.056.084-3.314 1.386C.654 2.708.33 4.962.33 4.962S0 7.608 0 10.254v2.481c0 2.647.33 5.293.33 5.293s.324 2.253 1.316 3.246c1.258 1.302 2.911 1.261 3.647 1.397 2.647.251 11.248.329 11.248.329s6.952-.01 11.581-.341c.647-.076 2.057-.083 3.315-1.385.992-.993 1.315-3.246 1.315-3.246s.33-2.646.33-5.293v-2.48c0-2.647-.33-5.293-.33-5.293z" fill-rule="evenodd"></path></svg></span><span class="css-1rwwusq e1xr6nc2">Zoopla YouTube channel</span></a>
#                         </li>
#                         <li class="css-1b9jro8 e1xr6nc1"><a href="https://uk.pinterest.com/zoopla" target="_blank" data-testid="social-link-pinterest"
#                             data-track-category="footer" data-track-action="clickout" data-track-label="pinterest"
#                             rel="noopener noreferrer" title="This link opens in a new window" class="eh8rboe0 css-190kehk e469udr0"><span role="presentation" aria-hidden="true" data-testid="pinterest" color="grey-aluminium" class="e5cetgg0 css-13falfm e1dxqi130"><svg viewBox="0 0 30 30" xmlns="http://www.w3.org/2000/svg"><path d="M30 15c0 2.721-.67 5.231-2.012 7.53a14.933 14.933 0 01-5.459 5.458C20.231 29.33 17.721 30 15 30c-1.445 0-2.865-.208-4.258-.625.768-1.21 1.276-2.279 1.524-3.203a709 709 0 001.054-4.121c.26.508.736.947 1.426 1.318a4.63 4.63 0 002.227.557c1.575 0 2.981-.446 4.218-1.338 1.237-.892 2.194-2.12 2.872-3.682.677-1.562 1.015-3.32 1.015-5.273a8.037 8.037 0 00-1.162-4.18c-.775-1.302-1.898-2.363-3.37-3.183-1.47-.82-3.13-1.23-4.98-1.23-1.367 0-2.643.188-3.828.565-1.185.378-2.19.88-3.017 1.504a10.286 10.286 0 00-2.13 2.159 8.93 8.93 0 00-1.308 2.529 8.523 8.523 0 00-.42 2.617c0 1.354.26 2.546.782 3.574.52 1.029 1.282 1.752 2.285 2.168.39.157.638.026.742-.39.026-.092.078-.293.156-.606.078-.312.13-.508.156-.586.079-.3.007-.58-.214-.84-.665-.794-.997-1.777-.997-2.949 0-1.966.68-3.655 2.041-5.068 1.361-1.413 3.142-2.12 5.342-2.12 1.966 0 3.5.535 4.6 1.602 1.1 1.068 1.65 2.455 1.65 4.16 0 2.214-.446 4.095-1.338 5.645-.892 1.55-2.034 2.324-3.427 2.324-.795 0-1.433-.283-1.914-.85-.482-.566-.632-1.246-.45-2.04.105-.456.277-1.065.518-1.827.24-.761.436-1.432.586-2.011.15-.58.224-1.071.224-1.475 0-.651-.175-1.191-.527-1.621-.351-.43-.853-.645-1.504-.645-.807 0-1.49.371-2.05 1.114-.56.742-.84 1.666-.84 2.773 0 .95.162 1.745.488 2.383l-1.934 8.164c-.221.911-.306 2.064-.254 3.457-2.682-1.185-4.85-3.014-6.504-5.488C.827 20.788 0 18.034 0 15c0-2.721.67-5.231 2.012-7.53A14.933 14.933 0 017.47 2.013C9.769.67 12.279 0 15 0s5.231.67 7.53 2.012a14.933 14.933 0 015.458 5.459C29.33 9.769 30 12.279 30 15z" fill-rule="nonzero"></path></svg></span><span class="css-1rwwusq e1xr6nc2">Zoopla Pinterest board</span></a>
#                         </li>
#                     </ul>
#                 </li>
#                 <li class="css-o9b79t e13yw60i3">
#                     <div class="css-mzz3rs ezrlox10">
#                         <h3 class="css-te0zen e13yw60i1">Legal and corporate information</h3>
#                         <ul class="css-y8aj3r ezrlox11">
#                             <li class="css-tx5jzt ezrlox12"><a href="/property/estimate/about/" data-track-category="footer" data-track-action="clickthrough"
#                                 data-track-label="zoopla estimates" class="ezrlox13 css-2dtoam e469udr0">Zoopla estimates</a>
#                             </li>
#                             <li class="css-tx5jzt ezrlox12"><a href="/property/streets/" data-track-category="footer" data-track-action="clickthrough"
#                                 data-track-label="street index" class="ezrlox13 css-2dtoam e469udr0">Street index</a>
#                             </li>
#                             <li class="css-tx5jzt ezrlox12"><a href="/sitemap/popular-areas/" data-track-category="footer" data-track-action="clickthrough"
#                                 data-track-label="popular areas" class="ezrlox13 css-2dtoam e469udr0">Popular areas</a>
#                             </li>
#                             <li class="css-tx5jzt ezrlox12">
#                                 <p>© 2020 Zoopla Limited. All rights reserved.</p>
#                             </li>
#                         </ul>
#                         <p class="css-18qqa04 e1jo3k1c0">Sold house prices provided by Land Registry/Registers of Scotland. © Crown
#                             copyright 2020.</p>
#                         <p class="css-18qqa04 e1jo3k1c0">*Zoopla Limited is an appointed representative of uSwitch Limited which
#                             is authorised and regulated by the Financial Conduct Authority (FRN 312850)
#                             to provide this mortgage comparison service.</p>
#                         <p class="css-18qqa04 e1jo3k1c0">**uSwitch Limited is authorised and regulated by the Financial Conduct
#                             Authority (FCA) under firm reference number 312850. The Home insurance
#                             comparison service is provided by Autonet Insurance Services Ltd, registered
#                             in England No. 3642372. Autonet Insurance Services Ltd has its registered
#                             office at Nile Street, Burslem, Stoke-on-Trent ST6 2BA United Kingdom.
#                             AutoNet Insurance Services Ltd is authorised and regulated by the Financial
#                             Conduct Authority (FCA) (Registration number: 308213).</p>
#                         <p class="css-18qqa04 e1jo3k1c0">***Based on a search within the London postcode areas (E, EC, N, NW, SE,
#                             SW, W, WC) on other UK online property portals. As of 11 Mar 2019.</p>
#                     </div>
#                 </li>
#             </ul>
#         </footer>
#     </div>
# </div>
#
# <script>
#     (function init(footerElm) {
#         const footer = document.querySelector('.z-bui-component[data-name="footer"]');
#         const trackingElements = footer.querySelectorAll('[data-track-category]');
#         for(let i = 0; i < trackingElements.length; i++) {
#             const elm = trackingElements[i];
#             elm.dataset.gaCategory = elm.dataset.trackCategory;
#             elm.dataset.gaAction = elm.dataset.trackAction;
#             elm.dataset.gaLabel = elm.dataset.trackLabel;
#         }
#         const anchors = footer.querySelectorAll('a');
#         for(let i = 0; i < anchors.length; i++) {
#             anchors[i].dataset.ajax = false;
#         }
#     })();
# </script>
#
#
#         </footer>
#
#
#
#
#
#     <script async src="https://z.zoocdn.com/www/ub/zoopla/static/scripts/modules/zoopla-de4f1e3fe6.home.js"></script>
#
#
#
#
#
#     <script>
#         (function() {
#
#             window.dataLayer = window.dataLayer || [];
#
#             function createCookie(name, value, nrOfDays) {
#                 var expires,
#                     currentDate,
#                     calculateTime;
#
#                 if (nrOfDays) {
#                     currentDate = new Date();
#                     calcMsFromDays = nrOfDays * 24 * 60 * 60 * 1000;
#                     currentDate.setTime(currentDate.getTime() + calcMsFromDays);
#                     expires = ' ;expires=' + currentDate.toGMTString();
#                 } else {
#                     expires = '';
#                 }
#                 document.cookie = name + '=' + value + expires + '; path=/;domain=zoopla.co.uk';
#             }
#
#             messageData =  'We use cookies to give you the best possible experience on our site, and so that we and third parties can show you more personalised ads, including adverts on other websites. By clicking "Accept", you agree to our use of cookies. '
#
#             var fragment = document.createDocumentFragment(),
#                 elBody = document.getElementsByTagName('BODY')[0],
#                 elFirstChild = elBody.firstChild,
#                 elWrap = document.createElement('div'),
#                 elHolder = document.createElement('div'),
#                 elCopy = document.createElement('p'),
#                 elLink = document.createElement('a'),
#                 elButton = document.createElement('button'),
#                 messageText = document.createTextNode(messageData),
#                 buttonText = document.createTextNode('Accept'),
#                 linkText = document.createTextNode('Find out more');
#
#
#             elWrap.setAttribute('class', 'cookie-banner is-rwd');
#             elHolder.setAttribute('class', 'container-wrap');
#             elCopy.setAttribute('class', 'cookie-banner__copy');
#             elLink.setAttribute('href', '/privacy/cookies');
#             elLink.setAttribute('target', '_blank');
#             elLink.setAttribute('rel', 'noopener noreferrer');
#             elLink.setAttribute('class', 'cookie-banner__link');
#             elButton.setAttribute('class', 'button');
#             elButton.setAttribute('type', 'button');
#             elButton.setAttribute('title', 'Agree to our use of cookies');
#             elButton.classList.add('cookie-banner__button');
#
#             elLink.appendChild(linkText);
#             elButton.appendChild(buttonText);
#             elCopy.appendChild(messageText);
#             elCopy.appendChild(elLink);
#
#             elHolder.appendChild(elCopy);
#             elHolder.appendChild(elButton);
#             elWrap.appendChild(elHolder);
#             fragment.appendChild(elWrap);
#
#             document.body.insertBefore(fragment, elFirstChild);
#
#             window.dataLayer.push({
#                 'event': 'GAEvent',
#                 'eventCategory': 'Cookie banner',
#                 'eventAction':'Impression',
#                 'eventLabel': 'Show banner',
#                 'eventNonInteraction': true
#             });
#
#             elButton.addEventListener('click', function(e) {
#                 elWrap.classList.add('js-cookie-accepted');
#                 elLink.setAttribute('aria-hidden', 'true');
#                 elButton.setAttribute('aria-hidden', 'true');
#                 createCookie('cookie_policy_acceptance', '1', 365);
#
#                 window.dataLayer.push({
#                     'event': 'GAEvent',
#                     'eventCategory': 'Cookie banner',
#                     'eventAction':'Click',
#                     'eventLabel': 'Accept cookies',
#                     'eventNonInteraction': true
#                 });
#
#             });
#         })();
#     </script>
#
#
#
#
#
#             <script async src="https://z.zoocdn.com/www/ub/zoopla/static/scripts/zoopla-fe4eb22835.header.js"></script>
#
#         <script>
#
#             function page_onload() {
#
#             }
#
#             window.onload = page_onload;
#
#         </script>
#
#
#
#
#
#
#               <script type="application/ld+json">[
#    {
#       "alternateName":"Zoopla Property Search",
#       "potentialAction":{
#          "target":"https://www.zoopla.co.uk/search/?q={search_term_string}",
#          "query-input":"required name=search_term_string",
#          "@type":"SearchAction"
#       },
#       "@context":"http://schema.org",
#       "url":"https://www.zoopla.co.uk/",
#       "name":"Zoopla",
#       "@type":"WebSite"
#    },
#    {
#       "logo":"https://www.zoopla.co.uk/static/images/logo-alt.png",
#       "@context":"http://schema.org",
#       "contactPoint":[
#          {
#             "areaServed":"UK",
#             "telephone":"+44 20 3544 1000",
#             "contactType":"Customer service",
#             "@type":"ContactPoint"
#          }
#       ],
#       "url":"https://www.zoopla.co.uk/",
#       "name":"Zoopla Property Group",
#       "sameas":[
#          "https://plus.google.com/+zoopla",
#          "https://twitter.com/zoopla",
#          "https://www.facebook.com/ZooplaUK",
#          "https://www.instagram.com/zoopla/",
#          "https://www.youtube.com/user/ZooplaUK",
#          "https://www.linkedin.com/company/zoopla/about/",
#          "https://www.pinterest.co.uk/zoopla/",
#          "https://en.wikipedia.org/wiki/ZPG_plc"
#       ],
#       "@type":"Organization"
#    }
# ]
# </script>
#
#
#     </body>
#
# </html>

# %% [markdown]
# ## Step 2: Finding the data by Parsing HTML
#
# Now that we have the page which we know contains the data, we need to find the information that we care about within it.
#
# The process of converting the string of text, which we know represents HTML, into structured HTML as well as maybe extracting information that we want from within it, is called **parsing**.

# %% [markdown]
# ### Converting the string to a HTML tree
#
# HTML is just a nested set of elements, all inside a single `<html>...</html>` tag.
# By looking at this top `html` node, and branching it's child nodes from it recursively, we can visualise the webpage as a tree. This is shown below.
#
# ![](./images/html_tree.jpg)
#
# # show webpage and markdown with this structure
#
# We can use the `lxml` library to turn the homogeneous string into a tree data structure.
# `lxml` has a module called etree which is a simple and efficient API for parsing and creating XML or HTML data.
# Using the HTML function.
#
# See more about `lxml.etree` [here](https://lxml.de/api/)

# %%
from lxml import etree

tree = etree.HTML(html_string) # use the HTML method to 
print(tree)
print(etree.tostring(tree)) # print the tree
# Out:
# <Element html at 0x18c01fc4648>
# b'<html class="no-js" xmlns="https://www.w3.org/1999/xhtml" xml:lang="en" lang="en-GB" xmlns:fb="https://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/">\n<head>\n\n    \n    <meta charset="utf-8"/>\n    <title>Zoopla &gt; Search Property to Buy, Rent, House Prices, Estate Agents</title>\n    \n\n        <meta name="description" content="Search for property with the UK\'s leading resource. Browse houses and flats for sale and to rent, and find estate agents in your area."/>\n\n        <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"/>\n\n    <meta name="p:domain_verify" content="be06f9b9d493189acc5cb456ca9a68e1"/>\n    <meta name="verify-v1" content="5sGBRIBu2OitdItUbuozS0V22pWw4WXsMP8K15vIKD0="/>\n    <meta name="msvalidate.01" content="20BD4007B12CDB4977964997AB208472"/>\n    <meta name="y_key" content="1a4dcbe953cadecb"/>\n    <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no"/>\n    <link rel="shortcut icon" type="image/x-icon" href="https://z.zoocdn.com/www/_b/static/images/favicon-37408e0919.ico"/>\n\n        <meta name="twitter:card" content="summary"/>\n    <meta name="twitter:app:name:iphone" content="zoopla"/>\n    <meta name="twitter:app:id:iphone" content="380932800"/>\n    <meta name="twitter:app:name:googleplay" content="zoopla"/>\n    <meta name="twitter:app:id:googleplay" content="com.zoopla.activity"/>\n\n        <meta name="twitter:app:url:iphone" content="zoopla:///"/>\n        <meta name="twitter:app:url:googleplay" content="android-app://com.zoopla.activity/zoopla/"/>\n\n\n\n\n        <meta property="fb:admins" content="100003926523449"/>\n        <meta property="twitter:account_id" content="19903963"/>\n\n\n\n    \n    <meta name="alexaVerifyID" content="wewxzTLpGKQ6OiSsFdJY3s7-QvE"/>\n    <link href="https://plus.google.com/118429606719656973951" rel="publisher"/>\n\n\n    <link rel="apple-touch-icon-precomposed" href="https://z.zoocdn.com/www/_b/static/images/apple-touch-icon-precomposed-bb48e93eb2.png"/>\n\n        \n    <link rel="dns-prefetch" href="//fonts.gstatic.com/"/>\n    <link rel="preconnect" href="//fonts.gstatic.com/" crossorigin=""/>\n\n\n\n\n    <style>\n        @font-face {\n            font-family: \'Lato\';\n            font-style: normal;\n            font-display: swap;\n            font-weight: 300;\n            src: local(\'Lato Light\'), local(\'Lato-Light\'), url(https://fonts.gstatic.com/s/lato/v15/S6u9w4BMUTPHh7USSwiPGQ3q5d0.woff2) format(\'woff2\');\n            unicode-range: U+0000-00FF, U+0131, U+0152-0153, U+02BB-02BC, U+02C6, U+02DA, U+02DC, U+2000-206F, U+2074, U+20AC, U+2122, U+2191, U+2193, U+2212, U+2215, U+FEFF, U+FFFD;\n        }\n        @font-face {\n            font-family: \'Lato\';\n            font-style: normal;\n            font-display: swap;\n            font-weight: 400;\n            src: local(\'Lato Regular\'), local(\'Lato-Regular\'), url(https://fonts.gstatic.com/s/lato/v15/S6uyw4BMUTPHjx4wXiWtFCc.woff2) format(\'woff2\');\n            unicode-range: U+0000-00FF, U+0131, U+0152-0153, U+02BB-02BC, U+02C6, U+02DA, U+02DC, U+2000-206F, U+2074, U+20AC, U+2122, U+2191, U+2193, U+2212, U+2215, U+FEFF, U+FFFD;\n        }\n        @font-face {\n            font-family: \'Lato\';\n            font-style: normal;\n            font-display: swap;\n            font-weight: 700;\n            src: local(\'Lato Bold\'), local(\'Lato-Bold\'), url(https://fonts.gstatic.com/s/lato/v15/S6u9w4BMUTPHh6UVSwiPGQ3q5d0.woff2) format(\'woff2\');\n            unicode-range: U+0000-00FF, U+0131, U+0152-0153, U+02BB-02BC, U+02C6, U+02DA, U+02DC, U+2000-206F, U+2074, U+20AC, U+2122, U+2191, U+2193, U+2212, U+2215, U+FEFF, U+FFFD;\n        }\n        @font-face {\n            font-family: \'Lato\';\n            font-style: normal;\n            font-display: swap;\n            font-weight: 900;\n            src: local(\'Lato Black\'), local(\'Lato-Black\'), url(https://fonts.gstatic.com/s/lato/v15/S6u9w4BMUTPHh50XSwiPGQ3q5d0.woff ...

# %% [markdown]
# This tree object that we've converted the string HTML into now has methods that can be used to find elements within it.
#
# Check out the lxml.html documentation [here](https://lxml.de/3.1/tutorial.html).

# %% [markdown]
# ### Finding tree elements within a `lxml.etree` using xpath
#
# Xpath is a query language for selecting nodes/branches/elements within a tree-like data structure like HTML or XML.
#
# Below is a very simple xpath expression. This one finds all of the button elements in the html
#
# ## `//button`
#
# The `//` says "anywhere in the tree" and the `button` says find elements that have the tag type button. So this xpath expression says "find button tags anywhere within the tree"
#
# The `xpath` method of `lxml.etree` takes in an xpath expression returns a list of all elements in the tree that match it.
#
# Below are more examples of how to use xpath
#
# `/button` find **child** (not all) tags of type button, of the element
#
# `//div/button` - finds all of the button tags inside div tags anywhere on the page
#
# `//div[@id='custom_id']` - finds all div tags with the attribute (`@`) `id` equal to `custom_id`, anywhere on the page
#
# If any of these don't make sense, let us know and look it up.
#
# Use the `//button` xpath expression as an argument to find the button on the page

# %%
buttons = tree.xpath('//button')
print(buttons) # returned from xpath expression
# Out:
# [<Element button at 0x18c02233bc8>]

# %% [markdown]
# The elements of the tree that match the xpath expression are returned from the call to the `.xpath` method of the tree. To see the text that each of the buttons contain we can check out their `.text` attribute. Let's use a list comprehension to explore this, and a few other attributes.

# %%
btn_texts = [b.text for b in buttons] # map each button to their text
print(btn_texts)
# Out:
# ['Search']

# %% [markdown]
# ## Using the developer console to identify the right xpath
#
# ### How to open the console
#
# Modern browsers come with tools to maximise web developers productivity and help find bugs.
#
# The developer console has a lot of different tools.
#
# Open your element inspector by pressing `CTRL + SHIFT + C`.
# It should open on the right hand side of your screen as shown below.
#
# The elements tab of the developer console shows you the HTML and CSS that make up the website code (actually it shows the DOM. Read more about what exactly the DOM is [here](https://css-tricks.com/dom/)).
#
# You can always close the developer console by clicking the cross in the corner.
#
# Pressing `CTRL + SHIFT + J` opens the javascript console and closes the developer console if it is already open.
#
# ![title](./images/dev_console_opened.png)
#
# Check out the zoopla website for yourself. Try using your selector to see the HTML structure of the page.
# ![](./images/form_selector.png)
#
# Now use your selector to find the location of the button as shown below.
#
# ![](./images/button_selector.png)
#
# As mentioned, the selector allows us to visualise the DOM and find elements within our webpage.

# %% [markdown]
# ### We can find elements, and then search for elements within them!
#
# Elements returned from finding them by xpath also have the same search methods. They are the same object type.

# %% [markdown]
# ### We can search for elements in more ways than just xpath
#
# There are loads of ways to find elements within HTML.
#
# Let's check what methods and properties of our tree object exist by calling the built-in `dir()` method.

# %%
print(dir(tree))
# Out:
# ['__bool__', '__class__', '__contains__', '__copy__', '__deepcopy__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', '_init', 'addnext', 'addprevious', 'append', 'attrib', 'base', 'clear', 'cssselect', 'extend', 'find', 'findall', 'findtext', 'get', 'getchildren', 'getiterator', 'getnext', 'getparent', 'getprevious', 'getroottree', 'index', 'insert', 'items', 'iter', 'iterancestors', 'iterchildren', 'iterdescendants', 'iterfind', 'itersiblings', 'itertext', 'keys', 'makeelement', 'nsmap', 'prefix', 'remove', 'replace', 'set', 'sourceline', 'tag', 'tail', 'text', 'values', 'xpath']

# %% [markdown]
# If we wanted to find the documentation which would explain all of these in detail, we should print it's type and then find the corresponding page in the docs.

# %%
print(type(tree))
# Out:
# <class 'lxml.etree._Element'>

# %% [markdown]
# The type of our tree is currently `lxml.etree._Element`.
#
# If we find the documentation, we can see all of the methods [here](https://lxml.de/api/lxml.etree._Element-class.html)
#
# Sometimes it's not easy, but use your element inspector, and consider the many ways to select elements.

# %%
all_children = tree.getchildren()
find = tree.find('div')

css = tree.cssselect()

print('all_children:')
print(all_children)
print()
print('using "find" method:')
print(find)
print()

tree.get_element_by_id('mn-advice')
tree.find_css('') # find by css 

tree.find_class(class_name)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-6c497a6304fa> in <module>
#       2 find = tree.find('div')
#       3
# ----> 4 css = tree.cssselect()
#       5
#       6 print('all_children:')
#
# src\lxml\etree.pyx in lxml.etree._Element.cssselect()
#
# TypeError: cssselect() takes exactly 1 positional argument (0 given)

# %% [markdown]
# ## Once you've got an element, you can do all kinds of things with it
#
# A likely thing that you'll want to do is get the text inside an element. This might be a house name for example. You can do this by getting the
#
# Find the documentation [here](https://lxml.de/3.1/parsing.html)

# %%
element = tree.xpath('//button')[0]

# this element has a load of different attributes
as_a_string = etree.tostring(element) # get element as string
tag_type = element.tag # get the type of the tag
element_text = element.text
element_text2 = element.text_content()

print('as a string:')
print(as_a_string)
print()
print('type of element:', tag_type)
print()
print('text in element:', element_text)
print()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-e1500c37b973> in <module>
#       5 tag_type = element.tag # get the type of the tag
#       6 element_text = element.text
# ----> 7 element_text2 = element.text_content()
#       8
#       9 print('as a string:')
#
# AttributeError: 'lxml.etree._Element' object has no attribute 'text_content'

# %% [markdown]
# ## Beyond just GETTING static HTML
#
#
# ### Why might using requests to get the website content not work?
#
# Some elements on webpages are inserted or manipulated by javascript code that runs only after the HTML is rendered.
#
# Some information that you want may be shown only after interacting with certain elements.
#
# The GET requests to the website just get the HTML file. They don't actually run the javascript code, or interact with the page after it renders. So parsing them for our data won't work.
#
# Again, there is a way around this. We can use a library called Selenium to take control of a browser that can then be programatically instructed to fill in forms, click elements, and find data on any webpage.

# %% [markdown]
# ## Selenium
#
# Selenium is a tool for programmatically controlling a browser. It's originally intended to be used for creating unit tests, but it can also be used to do anything that needs a browser to be controlled.
#
# Check out the docs [here](https://selenium-python.readthedocs.io/)
#
# ### Webdriving
#
# Selenium can "drive" a web browser. This means it can take full control of it and, find elements, click, scroll, execute js etc.
#
# You need to specify which browsers this webdriver will drive such as Chrome or Firefox. To drive a browser you need to have the driver installed. We'll use the chrome browser and download it's driver called Chromedriver.
#
# We'll have to install chromedriver to drive our chrome browser. You should ensure you have the correct version, which should be the same as the version of chrome which you wish to drive.
#
# [Check your chrome version here](https://help.zenplanner.com/hc/en-us/articles/204253654-How-to-Find-Your-Internet-Browser-Version-Number-Google-Chrome)
#
# [Download chromedriver from here](https://chromedriver.chromium.org/downloads)
#
# Add chromedriver to your path
#
# # how to do that
#
# ### Getting pages
#
# To start up Selenium automatically driving a browser, we need to instantiate a Selenium webdriver.
#
# `driver = webdriver.Chrome()`
#
# This will create a webdriver instance
#
# Walk through options

# %% [markdown]
# ### Finding elements in the HTML when using Selenium
#
# Selenium has it's own APIs for finding elements, including xpath and [many more]()
#
# `driver.find_elements_by_xpath`

# %%
from selenium import webdriver
from time import sleep

class Scraper:
    driver = webdriver.Chrome('chrome_driver/chromedriver') 
    #     driver = webdriver.Chrome() # create webdriver
    
    def scrape(self):
        self.driver.get('https://www.zoopla.co.uk/new-homes/property/london/?q=London&results_sort=newest_listings&search_source=new-homes')
        sleep(1)
        
        # try using find_element
        accept_cookies = self.driver.find_elements_by_xpath('//button[@data-responsibility="acceptAll"]')
        # this gets the first one which is not interactable so it doesnt work
        
        # print the contents of all elements which match the xpath expression to find the right one
        for c in accept_cookies:
            print(c.text)

        # try using find_elements
        accept_cookies = self.driver.find_elements_by_xpath('//button[@data-responsibility="acceptAll"]')[1]
        
        print(accept_cookies)
        # use loop to select correct element
        for c in accept_cookies:
            if c.text.lower() == 'accept all cookies':
                c.click()
                break        
        
s = Scraper()
s.scrape()
# Out:
# Accept all cookies
# <selenium.webdriver.remote.webelement.WebElement (session="3f7f58d3ba6e9f55d1f9245447700080", element="f6b80168-d935-479f-9750-742979ca5f9f")>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-5d9f94e153b0> in <module>
#      29
#      30 s = Scraper()
# ---> 31 s.scrape()
#
# <ipython-input-11-5d9f94e153b0> in scrape(self)
#      23         print(accept_cookies)
#      24         # use loop to select correct element
# ---> 25         for c in accept_cookies:
#      26             if c.text.lower() == 'accept all cookies':
#      27                 c.click()
#
# TypeError: 'WebElement' object is not iterable

# %% [markdown]
# ### Executing javascript
#
# driver.
#
# ### Running headless
#
# We can pass options to our webdriver when it starts up. One of these useful options is a flag that toggles whether selenium should actually show you the chrome tab which it is driving, or just run it silently in the background.
#
# You might not always have a output display. maybe you want to run this script on a server that doesn't have a screen. Running selenium without showing the browser is called running a headless browser (imagine the tab you would normally see being the head).

# %% [markdown]
# ### Assembling our cleaned dataset

# %% [markdown]
# ## Scrapy
#
# So far we have:
# - used the `requests` library to get content from webpages
# - used `lxml.html` to parse our html using xpath
#
# These tools we've covered so far work for many use-cases, not just web scraping.
# All of the tools that we need for scraping come as part of a specialised Python scraping library called Scrapy.
#
# Scrapy will help us to:
# - get webpage HTML
# - parse HTML
# - crawl through many websites in a single run
#
# ### Scrapy spiders
#
# Let's make our first spider in Scrapy

# %%
import scrapy

class BlogSpider(scrapy.Spider):
    name = 'blogspider'
    start_urls = ['https://blog.scrapinghub.com']

    def parse(self, response):
        for title in response.css('.post-header>h2'):
            yield {'title': title.css('a ::text').get()}

        for next_page in response.css('a.next-posts-link'):
            yield response.follow(next_page, self.parse)
